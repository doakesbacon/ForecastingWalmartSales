# %%
#import dependencies
import pandas as pd

# %%
#read in data
features = pd.read_csv("Resources/features.csv")
stores = pd.read_csv("Resources/stores.csv")
train = pd.read_csv("Resources/train.csv")

# %%
features
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
stores
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# ...

# %%
train
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
features_stores_merge = pd.merge(features,stores,how='left')
features_stores_merge
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# ...

# %%
all_merge = pd.merge(features_stores_merge,train,how='right')
all_merge
# Out:
#         Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0           1  2010-02-05        42.31       2.572        NaN        NaN
# 1           1  2010-02-12        38.51       2.548        NaN        NaN
# 2           1  2010-02-19        39.93       2.514        NaN        NaN
# 3           1  2010-02-26        46.63       2.561        NaN        NaN
# 4           1  2010-03-05        46.50       2.625        NaN        NaN
# ...       ...         ...          ...         ...        ...        ...
# 421565     45  2012-09-28        64.88       3.997    4556.61      20.64
# 421566     45  2012-10-05        64.89       3.985    5046.74        NaN
# 421567     45  2012-10-12        54.47       4.000    1956.28        NaN
# 421568     45  2012-10-19        56.47       3.969    2004.02        NaN
# 421569     45  2012-10-26        58.85       3.882    4018.91      58.08
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# ...

# %%
holiday_sales = all_merge.loc[(all_merge["IsHoliday"] == True)]
holiday_sales.reset_index(inplace=True,drop=True)
holiday_sales
# Out:
#        Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0          1  2010-02-12        38.51       2.548        NaN        NaN
# 1          1  2010-09-10        78.69       2.565        NaN        NaN
# 2          1  2010-11-26        64.52       2.735        NaN        NaN
# 3          1  2010-12-31        48.43       2.943        NaN        NaN
# 4          1  2011-02-11        36.39       3.022        NaN        NaN
# ...      ...         ...          ...         ...        ...        ...
# 29656     45  2011-09-09        71.48       3.738        NaN        NaN
# 29657     45  2011-11-25        48.71       3.492     140.87     384.82
# 29658     45  2011-12-30        37.79       3.389    3604.35   43941.56
# 29659     45  2012-02-10        37.00       3.640   15760.30    6113.95
# 29660     45  2012-09-07        75.70       3.911   11024.45      12.80
#
#        MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# ...

# %%
holiday_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29661 entries, 0 to 29660
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         29661 non-null  int64
#  1   Date          29661 non-null  object
#  2   Temperature   29661 non-null  float64
#  3   Fuel_Price    29661 non-null  float64
#  4   MarkDown1     11942 non-null  float64
#  5   MarkDown2     10722 non-null  float64
#  6   MarkDown3     11456 non-null  float64
#  7   MarkDown4     10970 non-null  float64
#  8   MarkDown5     11991 non-null  float64
#  9   CPI           29661 non-null  float64
#  10  Unemployment  29661 non-null  float64
#  11  IsHoliday     29661 non-null  bool
#  12  Type          29661 non-null  object
#  13  Size          29661 non-null  int64
#  14  Dept          29661 non-null  int64
#  15  Weekly_Sales  29661 non-null  float64
# dtypes: bool(1), float64(10), int64(3), object(2)
# memory usage: 3.4+ MB

# %%
holiday_sales["Date"] = pd.to_datetime(holiday_sales["Date"])
holiday_sales["Month"] = holiday_sales["Date"].dt.month
holiday_sales["Year"] = holiday_sales["Date"].dt.year
holiday_sales["Day"] = holiday_sales["Date"].dt.day
# Out:
# C:\Users\tyler\AppData\Local\Temp\ipykernel_16084\1267854364.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   holiday_sales["Day"] = holiday_sales["Date"].dt.day

# %%
holiday_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29661 entries, 0 to 29660
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         29661 non-null  int64
#  1   Date          29661 non-null  datetime64[ns]
#  2   Temperature   29661 non-null  float64
#  3   Fuel_Price    29661 non-null  float64
#  4   MarkDown1     11942 non-null  float64
#  5   MarkDown2     10722 non-null  float64
#  6   MarkDown3     11456 non-null  float64
#  7   MarkDown4     10970 non-null  float64
#  8   MarkDown5     11991 non-null  float64
#  9   CPI           29661 non-null  float64
#  10  Unemployment  29661 non-null  float64
#  11  IsHoliday     29661 non-null  bool
#  12  Type          29661 non-null  object
#  13  Size          29661 non-null  int64
#  14  Dept          29661 non-null  int64
#  15  Weekly_Sales  29661 non-null  float64
#  16  Month         29661 non-null  int32
# ...

# %%
holiday_sales
# Out:
#        Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0          1 2010-02-12        38.51       2.548        NaN        NaN
# 1          1 2010-09-10        78.69       2.565        NaN        NaN
# 2          1 2010-11-26        64.52       2.735        NaN        NaN
# 3          1 2010-12-31        48.43       2.943        NaN        NaN
# 4          1 2011-02-11        36.39       3.022        NaN        NaN
# ...      ...        ...          ...         ...        ...        ...
# 29656     45 2011-09-09        71.48       3.738        NaN        NaN
# 29657     45 2011-11-25        48.71       3.492     140.87     384.82
# 29658     45 2011-12-30        37.79       3.389    3604.35   43941.56
# 29659     45 2012-02-10        37.00       3.640   15760.30    6113.95
# 29660     45 2012-09-07        75.70       3.911   11024.45      12.80
#
#        MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# ...

# %%
holiday_map = {2: "Super Bowl", 9: "Labor Day", 11: "Thanksgiving", 12: "Christmas"}
holiday_sales["Holiday"] = holiday_sales["Month"].map(holiday_map)
holiday_sales
# Out:
# C:\Users\tyler\AppData\Local\Temp\ipykernel_16084\518259764.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   holiday_sales["Holiday"] = holiday_sales["Month"].map(holiday_map)
#        Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0          1 2010-02-12        38.51       2.548        NaN        NaN
# 1          1 2010-09-10        78.69       2.565        NaN        NaN
# 2          1 2010-11-26        64.52       2.735        NaN        NaN
# 3          1 2010-12-31        48.43       2.943        NaN        NaN
# 4          1 2011-02-11        36.39       3.022        NaN        NaN
# ...      ...        ...          ...         ...        ...        ...
# ...

# %%
holiday_sales_dropped = holiday_sales[["Date","Temperature", "Fuel_Price","CPI", "Unemployment", "Type", "Size", "Dept","Weekly_Sales", "Holiday","Year","Month","Day"]]
holiday_sales_dropped
# Out:
#             Date  Temperature  Fuel_Price         CPI  Unemployment Type  \
# 0     2010-02-12        38.51       2.548  211.242170         8.106    A
# 1     2010-09-10        78.69       2.565  211.495190         7.787    A
# 2     2010-11-26        64.52       2.735  211.748433         7.838    A
# 3     2010-12-31        48.43       2.943  211.404932         7.838    A
# 4     2011-02-11        36.39       3.022  212.936705         7.742    A
# ...          ...          ...         ...         ...           ...  ...
# 29656 2011-09-09        71.48       3.738  186.673738         8.625    B
# 29657 2011-11-25        48.71       3.492  188.350400         8.523    B
# 29658 2011-12-30        37.79       3.389  189.062016         8.523    B
# 29659 2012-02-10        37.00       3.640  189.707605         8.424    B
# 29660 2012-09-07        75.70       3.911  191.577676         8.684    B
#
#          Size  Dept  Weekly_Sales       Holiday  Year  Month  Day
# ...

# %% [markdown]
# SAVING HOLIDAY DATA AS JSON AND CSV

# %%
#holiday_sales_dropped.to_csv("C:/School/Homework/Project 4/ForecastingWalmartSales/Resources/holiday_data.csv")
#holiday_sales_dropped.to_json("C:/School/Homework/Project 4/ForecastingWalmartSales/Resources/holiday_data.json", orient='records')

# %%
sb10 = holiday_sales_dropped.loc[(holiday_sales_dropped["Holiday"] == "Super Bowl") & (holiday_sales_dropped["Year"] == 2010)]
sb10
# Out:
#             Date         CPI  Unemployment Type    Size  Dept  Weekly_Sales  \
# 0     2010-02-12  211.242170         8.106    A  151315     1      46039.49
# 10    2010-02-12  211.242170         8.106    A  151315     2      44682.74
# 20    2010-02-12  211.242170         8.106    A  151315     3      10887.84
# 30    2010-02-12  211.242170         8.106    A  151315     4      35351.21
# 40    2010-02-12  211.242170         8.106    A  151315     5      29620.81
# ...          ...         ...           ...  ...     ...   ...           ...
# 29611 2010-02-12  181.982317         8.992    B  118221    93       2665.98
# 29621 2010-02-12  181.982317         8.992    B  118221    94          2.94
# 29631 2010-02-12  181.982317         8.992    B  118221    95      41131.42
# 29641 2010-02-12  181.982317         8.992    B  118221    97       5011.36
# 29651 2010-02-12  181.982317         8.992    B  118221    98        553.25
#
#           Holiday  Year
# 0      Super Bowl  2010
# ...

# %%
sum = sb10["Weekly_Sales"].sum()
print(sum)
# Out:
# 48336677.63

# %%
holidays = ["Super Bowl", "Labor Day", "Thanksgiving", "Christmas"]
years = [2010, 2011, 2012]
for holiday in holidays:
    specific_holiday = holiday_sales_dropped.loc([holiday_sales_dropped["Holiday"] == holidays]) 
    total_sales = specific_holiday
